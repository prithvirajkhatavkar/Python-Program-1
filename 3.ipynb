# %% [markdown]
# <a href="https://colab.research.google.com/github/prithvirajkhatavkar/Python-Program-1/blob/main/3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=int(input("enter the value of a:"))
b=int(input("enter the value of b:"))
if a>b:
  print("a is greater than b")
elif a==b:
    print("a is equal to b")
else:
  print("a is less than b")

num=int(input("Enter a number to check if it's even or odd: "))
if num %2==0:
  print("The number is even")
else:
  print("The number is odd")

ch=input("enter the character:")
if ch.isupper():
  print("the character is uppercase")
elif ch.islower():
  print("the character is lowercase")
else:
  print("it is not an alphabet")

x=input("enter something:")
if x.isdigit():
  print("the input is a number")
elif x.isalpha():
  print("the input is character")
else:
  print("invalid input")
