# %% [markdown]
# <a href="https://colab.research.google.com/github/prithvirajkhatavkar/Python-Program-1/blob/main/2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Taking two numbers
a = 15
b = 5
sum = a +b

# Output: sum = 20
# Declare variables
a = 2
b = 1.3
c = "Hello"

# Display variables
print("value of a :", a)
print("value of b :", b)
print("value of c :", c)

# Display types of variables
print("Type of a :", type(a))
print("Type of b :", type(b))
print("Type of c :", type(c))
# Declare variables
a = 10    # integer
b = 6.7   # float

# Type casting
x = float(a)  # int to float
y = int(b)    # float to int

# Display result
print("Original value of a :", a)
print("Type :", type(a))

print("After casting a to float :", x)
print("Type :", type(x))
# Declare variables
a = 10
b = 5

# Logical AND
print("a > 5 and b > 2 :", a > 5 and b > 2)
# Out:
# value of a : 2
# value of b : 1.3
# value of c : Hello
# Type of a : <class 'int'>
# Type of b : <class 'float'>
# Type of c : <class 'str'>
# Original value of a : 10
# Type : <class 'int'>
# After casting a to float : 10.0
# Type : <class 'float'>
# a > 5 and b > 2 : True
